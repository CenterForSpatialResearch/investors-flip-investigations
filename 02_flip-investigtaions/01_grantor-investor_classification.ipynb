# %%
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 80)
from shapely.geometry import Point, LineString
from geopandas import GeoDataFrame
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime

# %% [markdown]
# ## Classifying investor purchases
#
# Process to classify deeds as (a) residential properties, (b) likely purchased by investors.
#
# ## 1. Selecting deeds that fall within residential parcels
#
# Using land use data from the city of Philadelphia (see original source [here](https://www.opendataphilly.org/dataset/land-use))

# %%
# read in land use file
landuse = gpd.read_file("data/Land_Use_2019/Land_Use.shp")

# %%
# creating a more narrow set of residential parcels
# just low and medium residential uses
res = landuse.loc[(landuse['C_DIG2DESC']=='Residential Medium') | 
                    (landuse['C_DIG2DESC']=='Residential Low')]

# dropping pacels with na values for their geometry
res = res.dropna(subset=['geometry'])

# reprojecting residential low/med only category
res = res.to_crs('epsg:2272')

# %%
# reading in the real estate tax transfer data
rtt = pd.read_csv("data/rtt_summary.csv")
# Out:
# /Users/adamvosburgh/opt/anaconda3/envs/geo-2021/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (26,34,39,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# selecting just deeds (not mortgages and other transfer taxes)
deeds = rtt.loc[rtt['document_type'] == "DEED"]
# adding a year column from the document date
deeds["sort_year"] = deeds['display_date'].astype(str).str[:4]
# Out:
# /Users/adamvosburgh/opt/anaconda3/envs/geo-2021/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# defining points from lat/lon
deeds_points = [Point(xy) for xy in zip(deeds.lat,deeds.lng)]
deedsgeo = GeoDataFrame(deeds, geometry=deeds_points)

# %%
# selecting only deeds with non zero state taxes
deedsgeo = deedsgeo.loc[deedsgeo["state_tax_amount"] > 0]

# and that also have an address field
deedsgeo= deedsgeo.loc[deedsgeo["address_low"]>0]

# %%
# setting the projection for the lat lon coordinates 
deedsgeo.crs = 'epsg:4326'

# %%
# reprojecting to: EPSG:2272: NAD83 / Pennsylvania South (ftUS)
deedsgeo = deedsgeo.to_crs('epsg:2272')

# %%
# spatial join between deeds and residential parcels (to find only those deeds within residential parcels)
deeds_res = gpd.sjoin(deedsgeo,res, how="inner",op="within")

#deeds_res

# %% [markdown]
# ## 2. Identify likely investor purchases
# First tag all grantors with corporate entity names. Then find all investors who purchased more than 2 properties in any one year span.
#
# ### 2A. Identifying Deeds with likely investors as the grantor based on grantor name
# First tag all investor named entities
#   - LLC
#   - LP
#   - LIMITED PARTNERSHIP
#   - CORP
#   - CORPORATION
#   - INC
#   - COMPANY
#   - LIMITED PARTNE
#   - L P
#   - L L C
#   - PARTNERSHIP
#   - LTD
#   - TRUST

# %%
# selecting just post-2000 deeds
deeds_res['sort_year'] = pd.to_numeric(deeds_res['sort_year'])
deeds_res = deeds_res.loc[deeds_res['sort_year']>1999]

# selecting investors by grantor name
inv = deeds_res['grantors'].str.contains(
    'LLC|LP|LIMITED PARTNERSHIP|CORP|CORPORATION|INC|COMPANY|LIMITED PARTNE|L P|L L C|PARTNERSHIP|LTD|TRUST'
    ,regex=True)

# converting investors series to dataframe
inv = inv.to_frame()

# merging with deeds
deeds_inv = deeds_res.merge(
    inv, left_index=True, right_index = True)
deeds_inv = deeds_inv.dropna(subset=['grantors_x'])

# creating a count column to allow grouping and count 
# for investor and owner by year 
deeds_inv['inv'] = deeds_inv['grantors_y'].apply(lambda x: 1 if x == True else 0)
deeds_inv['occ'] = deeds_inv['grantors_y'].apply(lambda x: 1 if x == False else 0)

# dropping duplicate object ids from the dataset
deeds_inv = deeds_inv.drop_duplicates(subset="objectid")

# %% [markdown]
# ### 2B. Classifying investor sales by multiple purchasers
# Identifying grantors who sold more than 2 properties in any one year period from the full set of non-investor classified deeds:

# %%
# finding multiple sellers from the full set of non-investor classified deeds
# selecting from just the non llc llp deeds
occ = deeds_inv.loc[deeds_inv['occ']==1]

# %%
# getting all deeds from sellers who are associated with more than one deed
multiple_purchasers = occ.groupby(
    "grantors_x").filter(lambda s: s['objectid'].count()>=2)

# %%
# converting date to datetime format
multiple_purchasers['display_date'] = multiple_purchasers[
    'display_date'].astype('datetime64[ns]')

# %%
# dropping unneeded columns
columns_multi = ['objectid','grantees','grantors_x',
                 'display_date','sort_year','street_address']
multiple_purchase_simple = multiple_purchasers[columns_multi]

# %%
multiple_purchase_simple[
    'elapsed'] = multiple_purchase_simple.sort_values(
    ['grantors_x','display_date']).groupby(
    'grantors_x')['display_date'].diff()

# converting timedelta column to an int type 
# to make it possible to filter below
multiple_purchase_simple[
    'elapsed_days'] = multiple_purchase_simple[
    'elapsed'].dt.days
# Out:
# /Users/adamvosburgh/opt/anaconda3/envs/geo-2021/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/adamvosburgh/opt/anaconda3/envs/geo-2021/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# filtering for deeds from grantors who sold two properties within 1 year of each other
multiple_investors = multiple_purchase_simple.groupby('grantors_x').filter(
    lambda x: x['elapsed_days'].min() <= 365)
multiple_investors['multi_invest'] = 1

# %% [markdown]
# ## 4. merging multiple purchase investors back with full set of deeds
#
# Compiling a comprehensive classification of investor purchases

# %%
deeds_multi = deeds_inv.merge(
    multiple_investors, left_on="objectid", right_on="objectid",how="left")

deeds_multi["investor_all"] = deeds_multi[
    "inv"] + deeds_multi["multi_invest"].fillna(0)
deeds_multi['owner_occup'] = deeds_multi[
    'investor_all'].apply(lambda x: 0 if x == 1 else 1)

# %%
# Saving classified deeds to speed up future processing time 
deeds_for_save = deeds_multi
deeds_for_save['elapsed'] = deeds_for_save['elapsed'].fillna(pd.Timedelta('999 days'))
deeds_for_save['elapsed'] = deeds_for_save['elapsed'].dt.days.astype('int16')
deeds_for_save['display_date_y'] = deeds_for_save['display_date_y'].astype(str)
deeds_for_save['grantor_inv'] = deeds_for_save['inv']
deeds_for_save['grantor_occ'] = deeds_for_save['occ']
# Out:
#         objectid  document_id document_type       display_date_x  \
# 0        7744699     50942296          DEED  2004-04-02 00:00:00
# 1        7744935     50092387          DEED  2000-05-25 00:00:00
# 2        7744943     50942514          DEED  2004-05-28 00:00:00
# 3        7744945     50942516          DEED  2004-05-28 00:00:00
# 4        7744231     50941882          DEED  2004-05-12 00:00:00
# ...          ...          ...           ...                  ...
# 501203  11937534     53751056          DEED  2020-11-12 00:00:00
# 501204  11937539     53751061          DEED  2020-11-05 00:00:00
# 501205  11937978     53751529          DEED  2020-11-11 00:00:00
# 501206  11937985     53751536          DEED  2020-11-09 00:00:00
# 501207  11937988     53751539          DEED  2020-10-30 00:00:00
#
#            street_address_x  zip_code  ward  \
# 0           3083 MEMPHIS ST   19134.0  25.0
# 1            3631 AVALON ST   19114.0  66.0
# 2            3430 ALDINE ST   19136.0  64.0
# 3             5809 AKRON ST   19149.0  62.0
# 4       1403 ROSE PETAL WAY   19111.0  56.0
# ...                     ...       ...   ...
# 501203        427 S 55TH ST   19143.0  60.0
# 501204       1739 S 12TH ST   19148.0  39.0
# 501205       1305 N 51ST ST   19131.0  44.0
# 501206     158 GREENDALE RD   19154.0  66.0
# 501207     4435 MITCHELL ST   19128.0  21.0
#
#                                              grantors_x_x  \
# 0                   MCCAFFERTY MARIE E; TUCKER MARGARET T
# 1       TAYLOR COLERIDGE; TAYLOR ROBERT TR; TAYLOR RON...
# 2                             ROWLAND JAMES; ROWLAND JOAN
# 3                                              LAVIN BETH
# 4                        CHAMPION DEVELOPMENT CORPORATION
# ...                                                   ...
# 501203       JOHNSON DARLENE ESTATE OF; JOHNSON GREGORY A
# 501204                        HUANG QI PING; LU RONG YUAN
# 501205                                       BS PROPS LLC
# 501206                                         BYRNE SEAN
# 501207                   SHAPIRO ERIC M; SHAPIRO NICOLE N
#
#                               grantees_x  cash_consideration  \
# 0                        IRWIN LEIGHANNE             58900.0
# 1                      FALLEN PAUL J III             92000.0
# 2                          RUTA JOSEPH M            123000.0
# 3                           DUFFIE JAMIE             93000.0
# 4                                NVR INC             68500.0
# ...                                  ...                 ...
# 501203                 PWBH HOLDINGS LLC             70000.0
# 501204              510 PHILADELPHIA LLC            385000.0
# 501205  TCS ANIKA HOMES ACQUISITIONS III             62500.0
# 501206    GORHAM MALLORY; GORHAM PATRICK            305000.0
# 501207        DARABI ALI; TOFIGH MAHSHID            295000.0
#
#         other_consideration  total_consideration  assessed_value  \
# 0                       NaN              58900.0             NaN
# 1                       0.0              92000.0             NaN
# 2                       NaN             123000.0             NaN
# 3                       NaN              93000.0             NaN
# 4                       NaN              68500.0             NaN
# ...                     ...                  ...             ...
# 501203                  0.0              70000.0         94100.0
# 501204                  0.0             385000.0        500900.0
# 501205                  0.0              62500.0         55300.0
# 501206                  0.0             305000.0             0.0
# 501207                  0.0             295000.0        241600.0
#
#         common_level_ratio  fair_market_value  state_tax_amount  \
# 0                      NaN           30699.84             589.0
# 1                      NaN           63936.00             920.0
# 2                      NaN           43066.56            1230.0
# 3                      NaN           45344.64             930.0
# 4                      NaN          305913.60             685.0
# ...                    ...                ...               ...
# 501203                1.06           99746.00             700.0
# 501204                1.06          530954.00            3850.0
# 501205                1.06           58618.00             625.0
# 501206                1.06               0.00            3050.0
# 501207                1.06          256096.00            2950.0
#
#         state_tax_percent  local_tax_amount  local_tax_percent  \
# 0                   100.0           1767.00              100.0
# 1                   100.0           2760.00              100.0
# 2                   100.0           3690.00              100.0
# 3                   100.0           2790.00              100.0
# 4                   100.0           2055.00              100.0
# ...                   ...               ...                ...
# 501203              100.0           2294.60              100.0
# 501204              100.0          12620.30              100.0
# 501205              100.0           2048.75              100.0
# 501206              100.0           9997.90              100.0
# 501207              100.0           9670.10              100.0
#
#         adjusted_cash_consideration  adjusted_other_consideration  \
# 0                           58900.0                           NaN
# 1                           92000.0                           NaN
# 2                          123000.0                           NaN
# 3                           93000.0                           NaN
# 4                           68500.0                           NaN
# ...                             ...                           ...
# 501203                      70000.0                           NaN
# 501204                     385000.0                           NaN
# 501205                      62500.0                           NaN
# 501206                     305000.0                           NaN
# 501207                     295000.0                           NaN
#
#         adjusted_total_consideration  adjusted_assessed_value  \
# 0                            58900.0                      NaN
# 1                            92000.0                      NaN
# 2                           123000.0                      NaN
# 3                            93000.0                      NaN
# 4                            68500.0                      NaN
# ...                              ...                      ...
# 501203                       70000.0                  94100.0
# 501204                      385000.0                 500900.0
# 501205                       62500.0                  55300.0
# 501206                      305000.0                      NaN
# 501207                      295000.0                 241600.0
#
#         adjusted_fair_market_value  adjusted_state_tax_amount  \
# 0                         30699.84                      589.0
# 1                         63936.00                      920.0
# 2                         43066.56                     1230.0
# 3                         45344.64                      930.0
# 4                        305913.60                      685.0
# ...                            ...                        ...
# 501203                    99746.00                      700.0
# 501204                   530954.00                     3850.0
# 501205                    58618.00                      625.0
# 501206                         NaN                     3050.0
# 501207                   256096.00                     2950.0
#
#         adjusted_local_tax_amount receipt_num         receipt_date  \
# 0                         1767.00         NaN  2004-06-07 00:00:00
# 1                         2760.00         NaN  2000-06-07 00:00:00
# 2                         3690.00         NaN  2004-06-08 00:00:00
# 3                         2790.00         NaN  2004-06-08 00:00:00
# 4                         2055.00         NaN  2004-06-07 00:00:00
# ...                           ...         ...                  ...
# 501203                    2294.60   20-111537  2020-11-18 00:00:00
# 501204                   12620.30   20-111541  2020-11-18 00:00:00
# 501205                    2048.75   20-111955  2020-11-19 00:00:00
# 501206                    9997.90   20-111957  2020-11-19 00:00:00
# 501207                    9670.10   20-111959  2020-11-19 00:00:00
#
#              recording_date        document_date condo_name unit_num  \
# 0       2004-06-07 00:00:00  2004-04-02 00:00:00        NaN      NaN
# 1       2000-06-07 00:00:00  2000-05-25 00:00:00        NaN      NaN
# 2       2004-06-08 00:00:00  2004-05-28 00:00:00        NaN      NaN
# 3       2004-06-08 00:00:00  2004-05-28 00:00:00        NaN      NaN
# 4       2004-06-07 00:00:00  2004-05-12 00:00:00        NaN      NaN
# ...                     ...                  ...        ...      ...
# 501203  2020-11-18 00:00:00  2020-11-12 00:00:00        NaN      NaN
# 501204  2020-11-18 00:00:00  2020-11-05 00:00:00        NaN      NaN
# 501205  2020-11-19 00:00:00  2020-11-11 00:00:00        NaN      NaN
# 501206  2020-11-19 00:00:00  2020-11-09 00:00:00        NaN      NaN
# 501207  2020-11-19 00:00:00  2020-10-30 00:00:00        NaN      NaN
#
#         address_low address_low_suffix address_low_frac  address_high  \
# 0            3083.0                NaN              NaN           NaN
# 1            3631.0                NaN              NaN           NaN
# 2            3430.0                NaN              NaN           NaN
# 3            5809.0                NaN              NaN           NaN
# 4            1403.0                NaN              NaN           NaN
# ...             ...                ...              ...           ...
# 501203        427.0                NaN              NaN           NaN
# 501204       1739.0                NaN              NaN           NaN
# 501205       1305.0                NaN              NaN           NaN
# 501206        158.0                NaN              NaN           NaN
# 501207       4435.0                NaN              NaN           NaN
#
#        street_predir street_name street_suffix street_postdir  reg_map_id  \
# 0                NaN     MEMPHIS            ST            NaN  022N240033
# 1                NaN      AVALON            ST            NaN  084N180294
# 2                NaN      ALDINE            ST            NaN  137N180119
# 3                NaN       AKRON            ST            NaN  139N020114
# 4                NaN  ROSE PETAL           WAY            NaN  154N130125
# ...              ...         ...           ...            ...         ...
# 501203             S        55TH            ST            NaN         NaN
# 501204             S        12TH            ST            NaN         NaN
# 501205             N        51ST            ST            NaN         NaN
# 501206           NaN   GREENDALE            RD            NaN         NaN
# 501207           NaN    MITCHELL            ST            NaN         NaN
#
#        matched_regmap  opa_account_num legal_remarks discrepancy  \
# 0          022N240033      251496000.0           NaN          no
# 1          084N180294      661087900.0           NaN          no
# 2          137N180119      642110500.0           NaN          no
# 3          139N020114      621440200.0           NaN          no
# 4          154N130125      562065112.0     SUB OF 33          no
# ...               ...              ...           ...         ...
# 501203     022S110194      603169300.0           NaN          no
# 501204     013S110242      394589505.0           NaN          no
# 501205     074N010162      442249600.0           NaN          no
# 501206     153N161057      662326800.0           NaN          no
# 501207     092N150153      212209600.0           NaN          no
#
#         property_count        lat        lng  sort_year_x  \
# 0                  1.0 -75.109769  39.987205         2004
# 1                  1.0 -74.997365  40.074151         2000
# 2                  1.0 -75.041471  40.038977         2004
# 3                  1.0 -75.078006  40.028446         2004
# 4                  1.0 -75.063039  40.070579         2004
# ...                ...        ...        ...          ...
# 501203             1.0 -75.232104  39.953379         2020
# 501204             1.0 -75.164977  39.927630         2020
# 501205             1.0 -75.223741  39.973420         2020
# 501206             1.0 -74.974204  40.074521         2020
# 501207             1.0 -75.216538  40.032338         2020
#
#                               geometry  index_right  OBJECTID C_DIG1  \
# 0       POINT (2708216.614 249254.488)       285538    280539      1
# 1       POINT (2738711.806 281873.930)       531365    530366      1
# 2       POINT (2726767.396 268684.790)       474917    474918      1
# 3       POINT (2716658.617 264538.633)       472581    472582      1
# 4       POINT (2720380.991 280007.281)       476313    475314      1
# ...                                ...          ...       ...    ...
# 501203  POINT (2674302.475 235936.154)       113838    113839      1
# 501204  POINT (2693388.546 227103.882)        56551     56552      1
# 501205  POINT (2676437.435 243300.688)       133749    132750      1
# 501206  POINT (2745186.255 282211.164)       529494    529495      1
# 501207  POINT (2677839.735 264812.672)       304405    305406      1
#
#          C_DIG1DESC C_DIG2          C_DIG2DESC C_DIG3  \
# 0       Residential     12  Residential Medium    121
# 1       Residential     11     Residential Low    112
# 2       Residential     12  Residential Medium    121
# 3       Residential     12  Residential Medium    121
# 4       Residential     11     Residential Low    111
# ...             ...    ...                 ...    ...
# 501203  Residential     12  Residential Medium    121
# 501204  Residential     12  Residential Medium    121
# 501205  Residential     12  Residential Medium    121
# 501206  Residential     11     Residential Low    112
# 501207  Residential     12  Residential Medium    121
#
#                       C_DIG3DESC       VACBLDG  YEAR   Shape__Are  Shape__Len  \
# 0           Residential Rowhouse  Fully Vacant  2014   952.673950  165.045972
# 1       Residential SemiDetached          None  2016  3395.618225  298.879760
# 2           Residential Rowhouse          None  2015  1717.321350  237.627137
# 3           Residential Rowhouse          None  2012  1555.363403  195.088770
# 4           Residential Detached          None  2013  6734.606567  352.840272
# ...                          ...           ...   ...          ...         ...
# 501203      Residential Rowhouse          None  2017  1244.145447  186.251552
# 501204      Residential Rowhouse          None  2014  1174.017639  168.742747
# 501205      Residential Rowhouse          None  2011   956.758545  158.537245
# 501206  Residential SemiDetached          None  2016  2324.438538  222.524693
# 501207      Residential Rowhouse          None  2013  1126.196533  180.266515
#
#        grantors_y  inv  occ                      grantees_y  \
# 0           False    0    1                             NaN
# 1           False    0    1                             NaN
# 2           False    0    1                             NaN
# 3           False    0    1                             NaN
# 4            True    1    0                             NaN
# ...           ...  ...  ...                             ...
# 501203      False    0    1               PWBH HOLDINGS LLC
# 501204      False    0    1            510 PHILADELPHIA LLC
# 501205       True    1    0                             NaN
# 501206      False    0    1  GORHAM MALLORY; GORHAM PATRICK
# 501207      False    0    1      DARABI ALI; TOFIGH MAHSHID
#
#                                         grantors_x_y display_date_y  \
# 0                                                NaN            NaT
# 1                                                NaN            NaT
# 2                                                NaN            NaT
# 3                                                NaN            NaT
# 4                                                NaN            NaT
# ...                                              ...            ...
# 501203  JOHNSON DARLENE ESTATE OF; JOHNSON GREGORY A     2020-11-12
# 501204                   HUANG QI PING; LU RONG YUAN     2020-11-05
# 501205                                           NaN            NaT
# 501206                                    BYRNE SEAN     2020-11-09
# 501207              SHAPIRO ERIC M; SHAPIRO NICOLE N     2020-10-30
#
#         sort_year_y  street_address_y  elapsed  elapsed_days  multi_invest  \
# 0               NaN               NaN      999           NaN           NaN
# 1               NaN               NaN      999           NaN           NaN
# 2               NaN               NaN      999           NaN           NaN
# 3               NaN               NaN      999           NaN           NaN
# 4               NaN               NaN      999           NaN           NaN
# ...             ...               ...      ...           ...           ...
# 501203       2020.0     427 S 55TH ST        0           0.0           1.0
# 501204       2020.0    1739 S 12TH ST        0           0.0           1.0
# 501205          NaN               NaN      999           NaN           NaN
# 501206       2020.0  158 GREENDALE RD        0           0.0           1.0
# 501207       2020.0  4435 MITCHELL ST        0           0.0           1.0
#
#         investor_all  owner_occup  grantor_inv  grantor_occ
# 0                0.0            1            0            1
# 1                0.0            1            0            1
# 2                0.0            1            0            1
# 3                0.0            1            0            1
# 4                1.0            0            1            0
# ...              ...          ...          ...          ...
# 501203           1.0            0            0            1
# 501204           1.0            0            0            1
# 501205           1.0            0            1            0
# 501206           1.0            0            0            1
# 501207           1.0            0            0            1
#
# [501208 rows x 77 columns]

# %%
# saving final list of grantors
with open("data/rtt_grantor-investors_classified.geojson",
          'w') as f:
    f.write(deeds_for_save.to_json())
